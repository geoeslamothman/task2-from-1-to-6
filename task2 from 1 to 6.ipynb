# %%
name=input()
print ("welcome",name)
# Out:
#  eslam
# welcome eslam

# %%
age=input("enter your age")
# Out:
# enter your age 39

# %%
print(age)
# Out:
# 39

# %%
name=input()
city=input()
# Out:
#  eslam
#  nasercity

# %%
print(name,"live in",city)
# Out:
# eslam live in nasercity

# %%
number=input(int)
number2=input(int)
# Out:
# <class 'int'> 50
# <class 'int'> 100

# %%
print(number,",",number2)
# Out:
# 50 , 100

# %%
name=input("enter your name")
age=input("enter your age")
college=input("enter the college")
# Out:
# enter your name eslam
# enter your age 39
# enter the college science

# %%
print(name,"has",age,"years old and studied at faculty of",college)
# Out:
# eslam has 39 years old and studied at faculty of science
